# %%
from langchain_groq import ChatGroq
from langchain_google_genai import ChatGoogle,GoogleGenerativeAIEmbeddings
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(
    model="",
    temperature=0.1,
    max_tokens=512,
)

response = model.invoke("What is the capital of France?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[23], line 7
#       1 model = ChatGroq(
#       2     model="groq/groq-llama-3-8b-chat",
#       3     temperature=0.1,
#       4     max_tokens=512,
#       5 )
# ----> 7 response = model.invoke("What is the capital of France?")
#       8 print(response)
#
# File ~/Desktop/LLMOps/env-llmops/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:395, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     383 @override
#     384 def invoke(
#     385     self,
#    (...)
#     390     **kwargs: Any,
#     391 ) -> BaseMessage:
#     392     config = ensure_config(config)
#     393     return cast(
#     394         "ChatGeneration",
# --> 395         self.generate_prompt(
#     396             [self._convert_input(input)],
#     397             stop=stop,
# ...
